# %% [markdown]
# # Predict Future Values of Emissions

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import json
import random
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, Flatten, InputLayer, LSTM, Dropout, BatchNormalization, Conv1D, MaxPooling1D
from keras.callbacks import EarlyStopping
from keras import backend as K

# %% [markdown]
# ## Read Data

# %%
# Read in emission data
emission_input = pd.read_csv('../../data/greenhouse_emissions/oeko-institut_sektorale_abgrenzung_treibhausgasemissionen_daten_sektor_monthly.csv')
emission_data = emission_input['Total_CO2_Emission'].values
emission_data = emission_data[0:len(emission_data)-6]
emission_data = emission_data.astype('float64')
emission_index = emission_input['date'].values
# Take only the emissions on which we have indicators
print(f"Shape output data: {emission_data.shape}")
#print(emission_index)
# Out:
# Shape output data: (366,)

# %%
data= pd.Series(emission_data)
first_date = emission_index[0]
last_date = emission_index[-1]
split_train = np.arange(0, len(data)-12)
split_test = np.arange((len(data)-12), len(data))
train_data = pd.Series(data, index=split_train)
test_data = pd.Series(data, index=split_test)
time_scope = emission_index

# %% [markdown]
# # Auto Sarima Model

# %%
# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(train_data, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,0,1)x(0,1,1,12) [intercept=True]; AIC=710.594, BIC=729.768, Time=2.874 seconds
# Fit ARIMA(0,0,0)x(0,1,0,12) [intercept=True]; AIC=1385.064, BIC=1392.733, Time=0.057 seconds
# Fit ARIMA(1,0,0)x(1,1,0,12) [intercept=True]; AIC=750.042, BIC=765.382, Time=1.516 seconds
# Fit ARIMA(0,0,1)x(0,1,1,12) [intercept=True]; AIC=1057.452, BIC=1072.791, Time=1.565 seconds
# Fit ARIMA(0,0,0)x(0,1,0,12) [intercept=False]; AIC=1455.623, BIC=1459.458, Time=0.053 seconds
# Fit ARIMA(1,0,1)x(0,1,0,12) [intercept=True]; AIC=935.748, BIC=951.087, Time=0.254 seconds
# Fit ARIMA(1,0,1)x(1,1,1,12) [intercept=True]; AIC=685.687, BIC=708.696, Time=4.562 seconds
# Fit ARIMA(1,0,1)x(1,1,0,12) [intercept=True]; AIC=751.923, BIC=771.097, Time=1.962 seconds
# Fit ARIMA(1,0,1)x(2,1,1,12) [intercept=True]; AIC=687.471, BIC=714.315, Time=11.671 seconds
# Fit ARIMA(1,0,1)x(1,1,2,12) [intercept=True]; AIC=687.465, BIC=714.309, Time=11.352 seconds
# Fit ARIMA(1,0,1)x(0,1,2,12) [intercept=True]; AIC=686.933, BIC=709.942, Time=9.818 seconds
# Fit ARIMA(1,0,1)x(2,1,0,12) [intercept=True]; AIC=719.590, BIC=742.599, Time=7.414 seconds
# Fit ARIMA(1,0,1)x(2,1,2,12) [intercept=True]; AIC=689.454, BIC=720.133, Time=21.891 seconds
# Fit ARIMA(0,0,1)x(1,1,1,12) [intercept=True]; AIC=1058.134, BIC=1077.308, Time=3.015 seconds
# Fit ARIMA(1,0,0)x(1,1,1,12) [intercept=True]; AIC=685.070, BIC=704.244, Time=3.745 seconds
# Fit ARIMA(1,0,0)x(0,1,1,12) [intercept=True]; AIC=710.097, BIC=725.436, Time=3.487 seconds
# Fit ARIMA(1,0,0)x(2,1,1,12) [intercept=True]; AIC=686.843, BIC=709.851, Time=9.905 seconds
# Fit ARIMA(1,0,0)x(1,1,2,12) [intercept=True]; AIC=686.842, BIC=709.851, Time=10.195 seconds
# Fit ARIMA(1,0,0)x(0,1,0,12) [intercept=True]; AIC=934.293, BIC=945.798, Time=0.145 seconds
# Fit ARIMA(1,0,0)x(0,1,2,12) [intercept=True]; AIC=686.448, BIC=705.622, Time=8.023 seconds
# Fit ARIMA(1,0,0)x(2,1,0,12) [intercept=True]; AIC=717.728, BIC=736.903, Time=4.566 seconds
# Fit ARIMA(1,0,0)x(2,1,2,12) [intercept=True]; AIC=688.828, BIC=715.672, Time=13.675 seconds
# Fit ARIMA(0,0,0)x(1,1,1,12) [intercept=True]; AIC=1340.666, BIC=1356.005, Time=2.262 seconds
# Fit ARIMA(2,0,0)x(1,1,1,12) [intercept=True]; AIC=685.621, BIC=708.630, Time=3.878 seconds
# Fit ARIMA(2,0,1)x(1,1,1,12) [intercept=True]; AIC=687.548, BIC=714.391, Time=7.851 seconds
# Total fit time: 145.769 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  354
# Model:             SARIMAX(1, 0, 0)x(1, 1, [1], 12)   Log Likelihood                -337.535
# Date:                              Tue, 11 Aug 2020   AIC                            685.070
# Time:                                      13:28:47   BIC                            704.244
# Sample:                                           0   HQIC                           692.708
#                                               - 354
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0430      0.030     -1.441      0.149      -0.101       0.015
# ar.L1          0.9627      0.018     52.644      0.000       0.927       0.999
# ar.S.L12      -0.3165      0.028    -11.379      0.000      -0.371      -0.262
# ma.S.L12      -0.7349      0.034    -21.678      0.000      -0.801      -0.668
# sigma2         0.4015      0.010     38.463      0.000       0.381       0.422
# ===================================================================================
# Ljung-Box (Q):                       47.09   Jarque-Bera (JB):              8152.00
# Prob(Q):                              0.21   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.81   Skew:                            -0.33
# Prob(H) (two-sided):                  0.27   Kurtosis:                        26.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Forecast
#to get accuracy predict last year as well
n_periods = 18
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
#index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='MS')
#index_of_fc = np.arange(len(data)-12, len(data)-12+n_periods)

index_of_fc = np.arange(len(data)-12, len(data)-12+n_periods)
index_of_test = np.arange(len(data)-12, len(data))
index_of_compare = np.arange(0,6)

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
test_series = pd.Series(test_data, index=index_of_test)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)
sarima_array = fitted[-7:-1]
sarima_compare = pd.Series(sarima_array, index=index_of_compare)

# Plot baseline, training, test and forecast
plt.figure(figsize=(20,6))
line1 = plt.plot(train_data, label='Original Data')
line3 = plt.plot(test_series, label='Test Data')
line2 = plt.plot(fitted_series, label='Prediction')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)
plt.legend(fontsize='x-large')
plt.grid()
plt.xticks(np.arange(len(time_scope)+1)[::12], time_scope[::12], rotation=30, fontsize=12)
#plt.xticks(np.arange(len(time_scope)), time_scope, rotation=30)
plt.xlim([120,380])
plt.xlabel("Timescope", fontsize=18)
plt.ylabel("Emissions in million tonnes CO2", fontsize=18)
plt.yticks(fontsize=18)
plt.title("Result SARIMA", fontsize=20)

plt.show()

# %%
# Accuracy metrics
fitted = fitted[0:12]
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    print("Accuracy of the model:")
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 
            'corr':corr, 'minmax':minmax})
forecast_accuracy(fitted, test_data)
# Out:
# Accuracy of the model:
# {'mape': 0.007037505139794171,
#  'me': 0.08894873886469057,
#  'mae': 0.4726882483910882,
#  'mpe': 0.000828340691553468,
#  'rmse': 0.5740652353976862,
#  'corr': 0.9986976708273446,
#  'minmax': 0.00699944624918869}

# %% [markdown]
# ## MLP Model

# %%
# Convert an array of values into a dataset matrix
def sliding_window(input, output, look_back=1, horizon=1, shuffle=False):
	dataX, dataY = [], []
	if len(input) != len(output):
		raise ValueError('Input and ouput do not have same length!')
	for i in range(len(input)-look_back-horizon):
		dataX.append(input[i:(i+look_back)])
		dataY.append(output[(i+look_back):(i+look_back+horizon)])
	# Shuffle windows
	if shuffle is True:
		dataX, dataY = shuffle(dataX, dataY, random_state=0)
	return np.array(dataX), np.array(dataY)

# %%
from keras import backend as K

def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
scaler = StandardScaler()
#emission_data = scaler.fit_transform(emission_data)

look_back = 12  # months
horizon = 6     # months
split_ratio = 0.8
shuffle = True

# Split into train and test sets
train_size = int(len(emission_data) * split_ratio)
test_size = len(emission_data) - train_size
if test_size < (look_back+horizon):
    raise ValueError('Split ratio too small. Increase test size!')

# %%
# Regressions forecast model with windowing method
def train_model(trainX, trainY, testX,  testY, lock_back, horizon):
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights=True)
    model = Sequential()
    # Flatten array if input is matrix
    if len(trainX.shape) >= 3:
        model.add(Flatten())
        model.add(Dense(look_back, input_dim=trainX.shape[2]*look_back, activation='relu'))
    model.add(Dense(24, input_dim=look_back, activation='relu'))
    model.add(Dense(12, activation='relu'))
    model.add(Dense(horizon))
    model.compile(loss='mean_squared_error', optimizer='adam')#, metrics=[r2_keras])
    model.fit(trainX, trainY, epochs=100, batch_size=2, verbose=2, callbacks=[es])
    model.summary()
    # Estimate model performance
    trainScore = model.evaluate(trainX, trainY, verbose=0)
    print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
    testScore = model.evaluate(testX, testY, verbose=0)
    print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))

    # Generate predictions for training
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)

    return model, trainPredict, testPredict

# %%
# Emissions as input
trainX, trainY = sliding_window(emission_data[0:train_size],
                                emission_data[0:train_size],
                                look_back,
                                horizon)
testX, testY = sliding_window(emission_data[train_size:len(emission_data)],
                              emission_data[train_size:len(emission_data)],
                              look_back,
                              horizon)

# %%
print("Shape of data:")
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# Shape of data:
# (274, 12)
# (274, 6)
# (56, 12)
# (56, 6)

# %% [markdown]
# ### Train Model

# %%
# Create and fit Multilayer Perceptron model for every indicator
trainPredictPlot = np.empty_like(emission_data)
trainPredictPlot[:] = np.nan
testPredictPlot = np.empty_like(emission_data)
testPredictPlot[:] = np.nan

# Train model and generate predictions
model, trainPredict, testPredict = train_model(trainX, trainY, testX, testY, look_back, horizon)

# Shift train predictions for plotting
for t in range(len(trainPredict)):
    trainPredictPlot[t+look_back:t+look_back+horizon] = trainPredict[t, :]
for t in range(len(testPredict)):
    testPredictPlot[len(trainPredict)+t+look_back+horizon:len(trainPredict)+
                    t+look_back+(horizon*2)] = testPredict[t, :]
# Out:
# Epoch 1/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 2580.2000
# Epoch 2/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 47.6370
# Epoch 3/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 27.8142
# Epoch 4/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 25.7398
# Epoch 5/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 22.9564
# Epoch 6/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 20.8825
# Epoch 7/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 17.2319
# Epoch 8/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 14.5813
# Epoch 9/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 13.7104
# Epoch 10/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 12.4316
# Epoch 11/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 12.1845
# Epoch 12/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 11.4443
# Epoch 13/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 11.2096
# Epoch 14/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 10.8880
# Epoch 15/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 11.3956
# Epoch 16/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 10.6701
# Epoch 17/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 10.3494
# Epoch 18/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.9580
# Epoch 19/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.7814
# Epoch 20/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.6201
# Epoch 21/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.3273
# Epoch 22/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.7707
# Epoch 23/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.0165
# Epoch 24/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.1199
# Epoch 25/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 9.1464
# Epoch 26/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.8548
# Epoch 27/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.5063
# Epoch 28/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.5781
# Epoch 29/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.5889
# Epoch 30/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.2989
# Epoch 31/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.6796
# Epoch 32/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.2124
# Epoch 33/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.2254
# Epoch 34/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.1684
# Epoch 35/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.6717
# Epoch 36/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.5154
# Epoch 37/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.8948
# Epoch 38/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.4345
# Epoch 39/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.2060
# Epoch 40/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 8.0147
# Epoch 41/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.2567
# Epoch 42/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 7.0958
# Epoch 43/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.8666
# Epoch 44/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.8270
# Epoch 45/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.3882
# Epoch 46/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.3245
# Epoch 47/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.8394
# Epoch 48/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.1908
# Epoch 49/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.8928
# Epoch 50/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.0832
# Epoch 51/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.0859
# Epoch 52/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.8146
# Epoch 53/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.8731
# Epoch 54/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.5419
# Epoch 55/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 6.3701
# Epoch 56/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.6661
# Epoch 57/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.6046
# Epoch 58/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.5240
# Epoch 59/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.0592
# Epoch 60/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.5046
# Epoch 61/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.6602
# Epoch 62/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.7100
# Epoch 63/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.6918
# Epoch 64/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.4554
# Epoch 65/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.7386
# Epoch 66/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.2681
# Epoch 67/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.1029
# Epoch 68/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.2001
# Epoch 69/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.1558
# Epoch 70/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.7364
# Epoch 71/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.6289
# Epoch 72/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.0548
# Epoch 73/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.6679
# Epoch 74/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.6766
# Epoch 75/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.9434
# Epoch 76/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.4731
# Epoch 77/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.8339
# Epoch 78/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.6835
# Epoch 79/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.6204
# Epoch 80/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.8633
# Epoch 81/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.5362
# Epoch 82/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.3572
# Epoch 83/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 5.1424
# Epoch 84/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.2741
# Epoch 85/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.5357
# Epoch 86/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.3977
# Epoch 87/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.3904
# Epoch 88/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.3484
# Epoch 89/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.2728
# Epoch 90/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.3037
# Epoch 91/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.7483
# Epoch 92/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.4370
# Epoch 93/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.5108
# Epoch 94/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.3879
# Epoch 95/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.8763
# Epoch 96/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.4454
# Epoch 97/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.4102
# Epoch 98/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.4284
# Epoch 99/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.4461
# Epoch 100/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 137/137 - 0s - loss: 4.2492
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 24)                312
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                300
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 78
# =================================================================
# Total params: 690
# Trainable params: 690
# Non-trainable params: 0
# _________________________________________________________________
# Train Score: 4.88 MSE (2.21 RMSE)
# Test Score: 2.93 MSE (1.71 RMSE)

# %%
# Forecast predictions
forecastPlot = np.zeros((len(emission_data) + horizon))
forecastPlot[:] = np.nan
mlp_compare = np.zeros(6)

X = np.zeros((1, look_back))
X[0] = emission_data[len(emission_data)-look_back:]
predict = model.predict(X)
forecastPlot[len(emission_data):len(emission_data)+horizon] = predict[:]
mlp_compare[0:6] = predict[:]

# Plot baseline, training, test and forecast
plt.figure(figsize=(20,6))
line1 = plt.plot(emission_data[:], label='Original Data')
line3 = plt.plot(trainPredictPlot[:], label='Train Data')
line2 = plt.plot(testPredictPlot[:], label='Test Data')
line4 = plt.plot(forecastPlot[:], label='Forecast')

plt.legend(fontsize='x-large')
plt.grid()
plt.xticks(np.arange(len(time_scope)+1)[::12], time_scope[::12], rotation=30, fontsize=12)
plt.xlim([120,380])
plt.xlabel("Timescope", fontsize=18)
plt.ylabel("Emissions in million tonnes CO2", fontsize=18)
plt.yticks(fontsize=18)
plt.title("Result MLP", fontsize=20)
plt.show()

#plt.xticks(np.arange(len(time_scope)), time_scope, rotation=30)

# %% [markdown]
# ## Compare SARIMA with MLP

# %%
#sarima_plot = fitted[-7:-1]
#mlp_plot[0:horizon] = predict[:]
#sarima_plot = fitted_series[-7:-1] 


#plot difference between the forecasts
plt.figure(figsize=(20,6))
line1 = plt.plot(sarima_compare, label='Sarima Prediction')
line2 = plt.plot(mlp_compare, label='MLP Prediction')

plt.legend(fontsize='x-large')
plt.grid()
plt.xticks(np.arange(6), ['2020-07','2020-08', '2020-09', '2020-10', '2020-11', '2020-12'], rotation=30, fontsize=16)



plt.xlabel("Timescope", fontsize=18)
plt.ylabel("Emissions in million tonnes CO2", fontsize=18)
plt.yticks(fontsize=18)
plt.title("Comparison Forecast SARIMA & MLP", fontsize=20)
plt.show()

# %%
# Comparation between SARIMA and MLP, plots below each other

fig, ax = plt.subplots(2, figsize=(20,12), sharex=True)

# MLP
ax[0].plot(emission_data[:], label='Original Data')
ax[0].plot(trainPredictPlot[:], label='Train Data')
ax[0].plot(testPredictPlot[:], label='Test Data')
ax[0].plot(forecastPlot[:], label='Forecast')
ax[0].set_title('Result MLP', fontsize=20)
ax[0].set_ylabel('Emission in million tonnes C02', fontsize=18)
ax[0].yaxis.set_tick_params(labelsize=18)
ax[0].legend(fontsize='x-large', loc='upper right')
ax[0].grid()

# Sarima
ax[1].plot(train_data, label='Original Data')
ax[1].plot(test_series, label='Test Data')
ax[1].plot(fitted_series, label='Prediction')
ax[1].fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)
ax[1].set_title('Result SARIMA', fontsize=20)
ax[1].set_ylabel('Emission in million tonnes C02', fontsize=18)
ax[1].yaxis.set_tick_params(labelsize=18)
ax[1].legend(fontsize='x-large', loc='upper right')
ax[1].grid()



plt.xticks(np.arange(len(time_scope)+1)[::12], time_scope[::12], rotation=30, fontsize=12)
plt.xlabel("Time scope", fontsize=18)
plt.tight_layout()
plt.xlim([120,380])
plt.setp(ax, ylim=[50,100])

plt.show()
